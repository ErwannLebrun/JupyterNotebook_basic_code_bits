# %%
# Input and Print:
name = input("Enter you name: ")
print("Hello " + name)
# Out:
# Enter you name: test
# Hello test

# %% [markdown]
# # Markdown cell type (use the # symbol to comment)
# Markdown, press Run to make it look like a title

# %%
# Plot a graph using Matplotlib Pyplot
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [3, 1, 4, 2]
plt.plot(x, y)
plt.show()
